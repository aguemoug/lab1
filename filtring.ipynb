# %% [markdown]
# # Image filtering via 2D Convolution
#
# ## Averaging
# This is done by convolving the image with a normalized box filter. It simply takes the average of all the pixels under kernel area and replaces the central element with this average.
#
# This is done by the function cv2.blur() or cv2.boxFilter(). Check the docs for more details about the kernel. We should specify the width and height of kernel. A 3x3 normalized box filter would look like this:
#
#
#  ![filter](filter2.png "3x3 mean filter")
#
#
# OpenCV provides a function, cv2.filter2D(), to convolve a kernel with an image.

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt # w use plt in rather than pyplot 

#helper functions defined in utility.py
from utility import *
img = cv.imread('cofee.jpg')

kernel = np.ones((3,3),np.float32)/9
dst = cv.filter2D(img,-1,kernel)
sbs(img,dst,"original","mean filtered")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-fa73c9887855> in <module>
#       9 kernel = np.ones((3,3),np.float32)/9
#      10 dst = cv.filter2D(img,-1,kernel)
# ---> 11 sbs(img,dst,"original","mean filtered")
#
# NameError: name 'sbs' is not defined

# %% [markdown]
# ## Gaussian Filtering
# To apply a gaussian filter we use a discrete approximation.
#
#
#  ![](gkr.png"")

# %%
img = cv.imread('cofee.jpg')

kernel = np.array(([[1, 2, 1], [2, 4, 2], [1, 2, 1]]), np.float32)/16


dst = cv.filter2D(img,-1,kernel)

plt.subplot(121),cv_show(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),cv_show(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()
